# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
from matplotlib.ticker import LinearLocator

# %%
#Getting region 270-355 for DIFF BUM HMM OUTPUT 

df_diff_bumhmm_output = pd.read_csv('C:/Users/maran/Desktop/diff_BUM_HMM_Project/Github/diff_BUM_HMM/35S_diffBUM_HMM_WT_vs_Erb1_diff_BUM_HMM_analysed.txt', sep="\t", header=0)
df_diff_bumhmm_output = df_diff_bumhmm_output.iloc [269:355, 1:3]

#df_diff_bumhmm_output= df_diff_bumhmm_output.iloc[0:10, :]

df_diff_bumhmm_output['difference_diffBUMHMM'] = df_diff_bumhmm_output['UM'] - df_diff_bumhmm_output['MU']

df_diff_bumhmm_output= df_diff_bumhmm_output.drop(['UM', 'MU'], axis=1)

#df_pea_output = df_pea_output.iloc[0:10, :]



df_diff_bumhmm_output.reset_index(drop=True)



df_diff_bumhmm_output.head()
# Out:
#      difference_diffBUMHMM
# 270          -1.585893e-07
# 271           1.407343e-13
# 272           1.036717e-11
# 273           3.946810e-28
# 274           3.802900e-28

# %%
#Getting region 270-355 FOR PEA DATA

df_pea_output = pd.read_csv('C:/Users/maran/Desktop/diff_BUM_HMM_Project/Github/diff_BUM_HMM/Data/35S_pre_rRNA_PEA_data.txt', sep="\t", header=0)
df_pea_output = df_pea_output.iloc[269:355, :]


df_pea_output['difference_PEA'] = df_pea_output['deltaErb'] - df_pea_output['delta5']

df_pea_output= df_pea_output.drop(['deltaErb', 'delta5'], axis=1)

#df_pea_output = df_pea_output.iloc[0:10, :]
df_pea_output
# Out:
#      positions  difference_PEA
# 269        270        0.000000
# 270        271        0.000000
# 271        272        0.251014
# 272        273        0.000000
# 273        274        0.000000
# 274        275        0.000000
# 275        276        0.175287
# 276        277        0.128568
# 277        278        0.000000
# 278        279        0.000000
# 279        280        0.000000
# 280        281        0.026300
# 281        282        0.396604
# 282        283        0.486786
# 283        284        0.000000
# 284        285        0.000000
# 285        286        0.000000
# 286        287        0.000000
# 287        288        0.000000
# 288        289        0.000000
# 289        290        0.000000
# 290        291        0.000000
# 291        292        0.000000
# 292        293        0.000000
# 293        294        0.000000
# 294        295        0.000000
# 295        296        0.000000
# 296        297        0.000000
# 297        298        0.000000
# 298        299        0.000000
# ..         ...             ...
# 325        326       -0.148704
# 326        327       -0.001820
# 327        328        0.218851
# 328        329        0.129167
# 329        330       -0.310479
# 330        331       -0.548586
# 331        332        0.124194
# 332        333        0.000000
# 333        334        0.148980
# 334        335        0.252971
# 335        336        0.247587
# 336        337        0.187893
# 337        338        0.114726
# 338        339        0.315154
# 339        340       -0.014307
# 340        341        0.064362
# 341        342       -0.548395
# 342        343        0.000000
# 343        344        0.000000
# 344        345        0.000000
# 345        346        0.000000
# 346        347        0.000000
# 347        348        0.000000
# 348        349        0.310946
# 349        350        0.000000
# 350        351        0.284771
# 351        352        0.000000
# 352        353        0.000000
# 353        354        0.386099
# 354        355       -0.103277
#
# [86 rows x 2 columns]

# %%
#MERGING THE DATAFRAMES 
new_df = df_pea_output.set_index('positions').join(df_diff_bumhmm_output)
new_df
# Out:
#            difference_PEA  difference_diffBUMHMM
# positions
# 270              0.000000          -1.585893e-07
# 271              0.000000           1.407343e-13
# 272              0.251014           1.036717e-11
# 273              0.000000           3.946810e-28
# 274              0.000000           3.802900e-28
# 275              0.000000           8.958519e-11
# 276              0.175287           6.808013e-22
# 277              0.128568           1.119753e-20
# 278              0.000000           1.371585e-34
# 279              0.000000           6.115684e-23
# 280              0.000000           1.497805e-05
# 281              0.026300           9.950746e-01
# 282              0.396604           9.985545e-01
# 283              0.486786           2.849179e-27
# 284              0.000000           8.166069e-78
# 285              0.000000           4.790286e-26
# 286              0.000000           7.401482e-10
# 287              0.000000           1.026336e-20
# 288              0.000000           1.591416e-26
# 289              0.000000           5.968215e-37
# 290              0.000000           5.429947e-35
# 291              0.000000           3.681830e-33
# 292              0.000000           4.257704e-22
# 293              0.000000           3.540301e-61
# 294              0.000000           5.816544e-47
# 295              0.000000           1.480093e-22
# 296              0.000000           3.429197e-94
# 297              0.000000           1.198197e-20
# 298              0.000000           8.058807e-16
# 299              0.000000           1.707711e-07
# ...                   ...                    ...
# 326             -0.148704           5.637020e-15
# 327             -0.001820           1.123082e-01
# 328              0.218851           9.999764e-01
# 329              0.129167           4.743206e-14
# 330             -0.310479          -2.160687e-41
# 331             -0.548586           2.028295e-15
# 332              0.124194           3.479297e-03
# 333              0.000000          -2.724987e-22
# 334              0.148980           5.436172e-15
# 335              0.252971           1.058758e-21
# 336              0.247587           2.368961e-09
# 337              0.187893           9.050874e-13
# 338              0.114726           2.397618e-02
# 339              0.315154          -4.287513e-05
# 340             -0.014307          -2.022407e-03
# 341              0.064362          -2.062810e-02
# 342             -0.548395          -1.211121e-11
# 343              0.000000          -1.555525e-50
# 344              0.000000          -1.053315e-47
# 345              0.000000          -3.633703e-27
# 346              0.000000          -1.339887e-24
# 347              0.000000          -1.223941e-19
# 348              0.000000           3.022483e-11
# 349              0.310946           3.138362e-20
# 350              0.000000           7.212392e-24
# 351              0.284771           2.334063e-16
# 352              0.000000           8.773232e-04
# 353              0.000000           1.282843e-02
# 354              0.386099          -4.253335e-04
# 355             -0.103277          -2.156417e-13
#
# [86 rows x 2 columns]

# %%
#THRESHOLDING DIFF BUM HMM OUTPUT - 0.05 - otherwise bugs later on 
new_df['UM'] = [0 if x<0.05 else x for x in new_df['UM']]
new_df['MU'] = [0 if x<0.05 else x for x in new_df['MU']]

# %%
new_df.reset_index()
# Out:
#     positions  difference_PEA  difference_diffBUMHMM
# 0         270        0.000000          -1.585893e-07
# 1         271        0.000000           1.407343e-13
# 2         272        0.251014           1.036717e-11
# 3         273        0.000000           3.946810e-28
# 4         274        0.000000           3.802900e-28
# 5         275        0.000000           8.958519e-11
# 6         276        0.175287           6.808013e-22
# 7         277        0.128568           1.119753e-20
# 8         278        0.000000           1.371585e-34
# 9         279        0.000000           6.115684e-23
# 10        280        0.000000           1.497805e-05
# 11        281        0.026300           9.950746e-01
# 12        282        0.396604           9.985545e-01
# 13        283        0.486786           2.849179e-27
# 14        284        0.000000           8.166069e-78
# 15        285        0.000000           4.790286e-26
# 16        286        0.000000           7.401482e-10
# 17        287        0.000000           1.026336e-20
# 18        288        0.000000           1.591416e-26
# 19        289        0.000000           5.968215e-37
# 20        290        0.000000           5.429947e-35
# 21        291        0.000000           3.681830e-33
# 22        292        0.000000           4.257704e-22
# 23        293        0.000000           3.540301e-61
# 24        294        0.000000           5.816544e-47
# 25        295        0.000000           1.480093e-22
# 26        296        0.000000           3.429197e-94
# 27        297        0.000000           1.198197e-20
# 28        298        0.000000           8.058807e-16
# 29        299        0.000000           1.707711e-07
# ..        ...             ...                    ...
# 56        326       -0.148704           5.637020e-15
# 57        327       -0.001820           1.123082e-01
# 58        328        0.218851           9.999764e-01
# 59        329        0.129167           4.743206e-14
# 60        330       -0.310479          -2.160687e-41
# 61        331       -0.548586           2.028295e-15
# 62        332        0.124194           3.479297e-03
# 63        333        0.000000          -2.724987e-22
# 64        334        0.148980           5.436172e-15
# 65        335        0.252971           1.058758e-21
# 66        336        0.247587           2.368961e-09
# 67        337        0.187893           9.050874e-13
# 68        338        0.114726           2.397618e-02
# 69        339        0.315154          -4.287513e-05
# 70        340       -0.014307          -2.022407e-03
# 71        341        0.064362          -2.062810e-02
# 72        342       -0.548395          -1.211121e-11
# 73        343        0.000000          -1.555525e-50
# 74        344        0.000000          -1.053315e-47
# 75        345        0.000000          -3.633703e-27
# 76        346        0.000000          -1.339887e-24
# 77        347        0.000000          -1.223941e-19
# 78        348        0.000000           3.022483e-11
# 79        349        0.310946           3.138362e-20
# 80        350        0.000000           7.212392e-24
# 81        351        0.284771           2.334063e-16
# 82        352        0.000000           8.773232e-04
# 83        353        0.000000           1.282843e-02
# 84        354        0.386099          -4.253335e-04
# 85        355       -0.103277          -2.156417e-13
#
# [86 rows x 3 columns]

# %%
#Calculate average of deltaSHAPE
#df_deltashape_rep1 = pd.read_csv('../../Data/Map files 35S/35S_deltaerb1_Vs_delta5_reps1.txt', sep="\t", header=0)
#df_deltashape_rep2 = pd.read_csv('../../Data/Map files 35S/35S_deltaerb1_Vs_delta5_reps2.txt', sep="\t", header=0)

#a=pd.DataFrame(index=np.arange(8659), columns=np.arange(10))

#for index, row in a.iterrows():
#    for index_2, row_2 in df_deltashape_rep1.iterrows():
 #       if index == row_2['Nuc']:
            
            #a.loc[index:index+1,:] = df_deltashape_rep1.loc[index_2:index_2+1,:].values
            

#columns = df_deltashape_rep1.columns   
#print(columns)
#for j in a.index:
#            data.loc[j,]=
        
        
#            end = int(data.loc[j,"end"])
#            coordinates = np.arange(start,end)
#            df.loc[coordinates,protein] = 1

# %%
#Calculate average of deltaSHAPE
df_deltashape_rep1 = pd.read_csv('../../Data/Map files 35S/35S_deltaerb1_Vs_delta5_reps1.txt', sep="\t", header=0)
df_deltashape_rep2 = pd.read_csv('../../Data/Map files 35S/35S_deltaerb1_Vs_delta5_reps2.txt', sep="\t", header=0)


df_deltashape_rep1['average_deltaSHAPE']=0
    
for index, row in df_deltashape_rep1.iterrows():    
    for index_2, row_2 in df_deltashape_rep2.iterrows():
        if row['Nuc'] == row_2['Nuc']:
            a = np.array([row['DeltaSHAPE'], row_2['DeltaSHAPE']])
            df_deltashape_rep1.loc[row.name,'average_deltaSHAPE'] = np.mean(a)


for index, row in df_deltashape_rep1.iterrows():    
    for index_2, row_2 in df_deltashape_rep2.iterrows():
        if row['average_deltaSHAPE']  == 0 and row_2['DeltaSHAPE'] != 0:
            df_deltashape_rep1.loc[row.name,'average_deltaSHAPE'] = row_2['DeltaSHAPE']
            
        
           
        
        
df_deltashape_rep1           
        
#FURTHER WORK MUST BE DONE HERE - TO MAKE A CORRECT RANGE OF VALUES THAT INCLUDE THE AVERAGE OF THE DEALTA SHAPE VALUES OVER THE SPECIFIED RANGE
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a928ff59b38f> in <module>
#      16     for index_2, row_2 in df_deltashape_rep2.iterrows():
#      17         if row['average_deltaSHAPE']  == 0 and row_2['DeltaSHAPE'] != 0:
# ---> 18             df_deltashape_rep1.loc[row.name,'average_deltaSHAPE'] = row_2['DeltaSHAPE']
#      19
#      20
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     187             key = com._apply_if_callable(key, self.obj)
#     188         indexer = self._get_setitem_indexer(key)
# --> 189         self._setitem_with_indexer(indexer, value)
#     190
#     191     def _validate_key(self, key, axis):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     613                 # scalar
#     614                 for item in labels:
# --> 615                     setter(item, value)
#     616
#     617         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in setter(item, v)
#     541
#     542                 # reset the sliced object if unique
# --> 543                 self.obj[item] = s
#     544
#     545             def can_do_equal_len():
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3193         self._ensure_valid_index(value)
#    3194         value = self._sanitize_column(key, value)
# -> 3195         NDFrame._set_item(self, key, value)
#    3196
#    3197         # check if we are modifying a copy
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    2598
#    2599     def _set_item(self, key, value):
# -> 2600         self._data.set(key, value)
#    2601         self._clear_item_cache()
#    2602
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in set(self, item, value, check)
#    4251
#    4252         blknos = self._blknos[loc]
# -> 4253         blklocs = self._blklocs[loc].copy()
#    4254
#    4255         unfit_mgr_locs = []
#
# KeyboardInterrupt:

# %%
#Getting region 270-355 FOR DELTASHAPE

df_deltashape = pd.read_csv('../../Data/SHAPE_deltaSHAPE_35S/shape_delta_shape_35S.txt', sep="\t", header=0)



df_deltashape = df_deltashape.iloc[269:355, :]

#print(df_deltashape.columns)
df_deltashape = df_deltashape[[" Nuc","DSHAPE" ]]
df_deltashape

new_df_2 = df_deltashape.set_index(' Nuc').join(new_df)

new_df_2
# Out:
#         DSHAPE  difference_PEA  difference_diffBUMHMM
df_dstruct = pd.read_csv('C:/Users/maran/Desktop/diff_BUM_HMM_Project/Github/diff_BUM_HMM/output_dStruct_35S.txt', sep="\t", header=0)
df_dstruct = df_dstruct.iloc[269:355, :]
df_dstruct= df_dstruct.rename_axis('positions').reset_index()
#df_pea_output = df_pea_output.iloc[0:10, :]
#df_dstruct.head



new_df_2.reset_index()


new_df_2 = df_dstruct.set_index('positions').join(new_df_2)

# %%
new_df_2
# Out:
#                  A1        A2        B1        B2    DSHAPE  difference_PEA  \
# positions
# 270        0.026584  0.000000  0.014596  0.000000  0.000000        0.000000
# 271        0.031493  0.000000  0.064782  0.000000  0.000000        0.000000
# 272        0.012831  0.000902  0.063383  0.000000  0.000000        0.251014
# 273        0.000000  0.000000  0.011836  0.000000  0.000000        0.000000
# 274        0.000000  0.000000  0.060982  0.000000 -0.087173        0.000000
# 275        0.023887  0.000000  0.126413  0.000000 -0.081639        0.000000
# 276        0.045883  0.000000  0.083320  0.000000 -0.086475        0.175287
# 277        0.006710  0.000000  0.050115  0.000000  0.000000        0.128568
# 278        0.000000  0.000000  0.058735  0.000000  0.000000        0.000000
# 279        0.004720  0.000000  0.010071  0.000000  0.000000        0.000000
# 280        0.047185  0.007812  0.114555  0.004525  0.000000        0.000000
# 281        0.007050  0.000000  0.191625  0.044275 -0.148760        0.026300
# 282        0.000000  0.000000  0.637922  0.744183 -0.175584        0.396604
# 283        0.000000  0.000000  0.000000  0.000000 -0.155732        0.486786
# 284        0.000000  0.000000  0.000000  0.000000 -0.107111        0.000000
# 285        0.000000  0.000000  0.000000  0.000000 -0.093369        0.000000
# 286        0.061583  0.000000  0.091287  0.006713 -0.080102        0.000000
# 287        0.015259  0.000000  0.202838  0.000000  0.000000        0.000000
# 288        0.000000  0.001756  0.041043  0.000000  0.000000        0.000000
# 289        0.000000  0.000000  0.000000  0.000000  0.000000        0.000000
# 290        0.024892  0.000000  0.109343  0.000000  0.000000        0.000000
# 291        0.000000  0.000000  0.062476  0.000000  0.000000        0.000000
# 292        0.000000  0.000000  0.000000  0.011153  0.000000        0.000000
# 293        0.000000  0.000000  0.000000  0.000000  0.000000        0.000000
# 294        0.000000  0.000000  0.000000  0.000000  0.000000        0.000000
# 295        0.000000  0.000000  0.000000  0.045040  0.000000        0.000000
# 296        0.000000  0.000000  0.000000  0.000000  0.000000        0.000000
# 297        0.000000  0.000000  0.064374  0.000000 -0.065171        0.000000
# 298        0.002001  0.000000  0.223585  0.000000 -0.090159        0.000000
# 299        0.012839  0.000000  0.066458  0.066057 -0.158743        0.000000
# ...             ...       ...       ...       ...       ...             ...
# 326        0.000000  0.000000  0.221705  0.000000 -0.129262       -0.148704
# 327        0.557038  0.258005  1.385671  0.883871 -0.160273       -0.001820
# 328        0.173499  0.009528  0.783365  0.660390 -0.146936        0.218851
# 329        0.121372  0.000000  0.180585  0.000000 -0.089647        0.129167
# 330        0.000000  0.000000  0.000000  0.000000 -0.075355       -0.310479
# 343                -1.555525e-50
# 344                -1.053315e-47
# 345                -3.633703e-27
# 346                -1.339887e-24
# 347                -1.223941e-19
# 348                 3.022483e-11
# 349                 3.138362e-20
# 350                 7.212392e-24
# 351                 2.334063e-16
# 352                 8.773232e-04
# 353                 1.282843e-02
# 354                -4.253335e-04
# 355                -2.156417e-13
#
# [86 rows x 7 columns]

# %%
new_df_2 = new_df_2[['difference_diffBUMHMM','difference_PEA', 'DSHAPE','A1','A2', 'B1', 'B2']]

new_df_2.columns = ['diff diffBUMHMM deltaErb minus delta5 ','diff PEA deltaErb minus delta5', 'deltaSHAPE', 'SHAPE norm reactivity delta5 rep1','SHAPE norm reactivity delta5 rep2', 'SHAPE norm reactivity deltaerb1 rep1','SHAPE norm reactivity deltaerb1 rep2' ]
new_df_2




#print(new_df_2.columns)
# Out:
#            diff diffBUMHMM deltaErb minus delta5   \
# positions
# 270                                 -1.585893e-07
# 271                                  1.407343e-13
# 272                                  1.036717e-11
# 273                                  3.946810e-28
# 274                                  3.802900e-28
# 275                                  8.958519e-11
# 276                                  6.808013e-22
# 277                                  1.119753e-20
# 278                                  1.371585e-34
# 279                                  6.115684e-23
# 280                                  1.497805e-05
# 281                                  9.950746e-01
# 282                                  9.985545e-01
# 283                                  2.849179e-27
# 284                                  8.166069e-78
# 285                                  4.790286e-26
# 286                                  7.401482e-10
# 287                                  1.026336e-20
# 288                                  1.591416e-26
# 289                                  5.968215e-37
# 290                                  5.429947e-35
# 291                                  3.681830e-33
# 292                                  4.257704e-22
# 293                                  3.540301e-61
# 294                                  5.816544e-47
# 295                                  1.480093e-22
# 296                                  3.429197e-94
# 297                                  1.198197e-20
# 298                                  8.058807e-16
# 299                                  1.707711e-07
# ...                                           ...
# 326                                  5.637020e-15
# 327                                  1.123082e-01
# 328                                  9.999764e-01
# 329                                  4.743206e-14
# 330                                 -2.160687e-41
# 331                                  2.028295e-15
# 332                                  3.479297e-03
# 333                                 -2.724987e-22
# 334                                  5.436172e-15
# 335                                  1.058758e-21
# 336                                  2.368961e-09
# 337                                  9.050874e-13
# 338                                  2.397618e-02
# 339                                 -4.287513e-05
# 340                                 -2.022407e-03
# 341                                 -2.062810e-02
# 342                                 -1.211121e-11
# 343                                 -1.555525e-50
# 344                                 -1.053315e-47
# 345                                 -3.633703e-27
# 346                                 -1.339887e-24
# 347                                 -1.223941e-19
# 348                                  3.022483e-11
# 349                                  3.138362e-20
# 350                                  7.212392e-24
# 351                                  2.334063e-16
# 352                                  8.773232e-04
# 353                                  1.282843e-02
# 354                                 -4.253335e-04
# 355                                 -2.156417e-13
#
#            diff PEA deltaErb minus delta5  deltaSHAPE  \
# positions
# 270                              0.000000    0.000000
# 271                              0.000000    0.000000
# 272                              0.251014    0.000000
# 273                              0.000000    0.000000
# 274                              0.000000   -0.087173
# 275                              0.000000   -0.081639
# 276                              0.175287   -0.086475
# 277                              0.128568    0.000000
# 278                              0.000000    0.000000
# 279                              0.000000    0.000000
#            SHAPE norm reactivity delta5 rep2  \
# positions
# 270                                 0.000000
# 271                                 0.000000
# 272                                 0.000902
# 273                                 0.000000
# 274                                 0.000000
# 275                                 0.000000
# 276                                 0.000000
# 277                                 0.000000
# 278                                 0.000000
# 279                                 0.000000
# 280                                 0.007812
# 281                                 0.000000
# 282                                 0.000000
# 283                                 0.000000
# 284                                 0.000000
# 285                                 0.000000
# 286                                 0.000000
# 287                                 0.000000
# 288                                 0.001756
# 289                                 0.000000
# 290                                 0.000000
# 291                                 0.000000
# 292                                 0.000000
# 293                                 0.000000
# 294                                 0.000000
# 295                                 0.000000
# 296                                 0.000000
# 297                                 0.000000
# 298                                 0.000000
# 299                                 0.000000
# ...                                      ...
# 326                                 0.000000
# 327                                 0.258005
# 328                                 0.009528
# 329                                 0.000000
# 330                                 0.000000
# 331                                 0.000000
# 332                                 0.000000
# 333                                 0.000000
# 334                                 0.000000
# 335                                 0.000000
# 336                                 0.000000
# 337                                 0.000000
# 338                                 0.736450
# 339                                 0.861267
# 340                                 2.472710
# 341                                 1.007182
# 342                                 0.097632
# 343                                 0.000000
# 344                                 0.000000
# 345                                 0.000000
# 346                                 0.118643
# 347                                 0.085148
# 348                                 0.000000
# 349                                 0.000000
# 350                                 0.087014
# 351                                 0.000000
# 352                                 0.136353
# 353                                 0.813603
# 354                                 1.835039
# 355                                 0.000000
#
#            SHAPE norm reactivity deltaerb1 rep1  \
# positions
# 270                                    0.014596
# 271                                    0.064782
# 272                                    0.063383
# 273                                    0.011836
# 274                                    0.060982
# 275                                    0.126413
# 276                                    0.083320
# 277                                    0.050115
# 278                                    0.058735
# 279                                    0.010071
# 280                                    0.114555
# 281                                    0.191625
# 282                                    0.637922
# 283                                    0.000000
# 284                                    0.000000
# 285                                    0.000000
# 286                                    0.091287
# 287                                    0.202838
# 288                                    0.041043
# 289                                    0.000000
# 290                                    0.109343
# 291                                    0.062476
# 292                                    0.000000
# 293                                    0.000000
# 294                                    0.000000
# 295                                    0.000000
# 296                                    0.000000
# 297                                    0.064374
# 298                                    0.223585
# 299                                    0.066458
# ...                                         ...
# 326                                    0.221705
# 327                                    1.385671
# 328                                    0.783365
# 329                                    0.180585
# 330                                    0.000000
# 331                                    0.222146
# 332                                    0.135093
# 333                                    0.044965
# 334                                    0.148980
# 335                                    0.045494
# 336                                    0.093017
# 337                                    0.269417
# 338                                    0.774346
# 339                                    0.579604
# 340                                    1.033732
# 341                                    0.223553
# 342                                    0.000000
# 343                                    0.000000
# 344                                    0.000000
# 345                                    0.000000
# 346                                    0.000000
# 347                                    0.074712
# 348                                    0.256434
# 349                                    0.106574
# 350                                    0.000000
# 351                                    0.247528
# 352                                    0.476943
# 353                                    1.175464
# 354                                    2.054480
# 355                                    0.233209
#
#            SHAPE norm reactivity deltaerb1 rep2
# positions
# 270                                    0.000000
# 271                                    0.000000
# 272                                    0.000000
# 273                                    0.000000
# 274                                    0.000000
# 275                                    0.000000
# 276                                    0.000000
# 277                                    0.000000
# 278                                    0.000000
# 279                                    0.000000
# 280                                    0.004525
# 281                                    0.044275
# 282                                    0.744183
# 283                                    0.000000
# 284                                    0.000000
# 285                                    0.000000
# 286                                    0.006713
# 287                                    0.000000
# 288                                    0.000000
# 289                                    0.000000
# 290                                    0.000000
# 291                                    0.000000
# 292                                    0.011153
# 293                                    0.000000
# 294                                    0.000000
# 295                                    0.045040
# 296                                    0.000000
# 297                                    0.000000
# 298                                    0.000000
# 299                                    0.066057
# ...                                         ...
# 326                                    0.000000
# 327                                    0.883871
# 328                                    0.660390
# 329                                    0.000000
# 330                                    0.000000
# 331                                    0.000000
# 332                                    0.042891
# 333                                    0.000000
# 334                                    0.000000
# 335                                    0.000000
# 336                                    0.000000
# 337                                    0.000000
# 338                                    0.933664
# 339                                    0.384905
# 340                                    0.593638
# 341                                    0.000000
# 342                                    0.000000
# 343                                    0.000000
# 344                                    0.000000
# 345                                    0.000000
# 346                                    0.000000
# 347                                    0.000000
# 348                                    0.000000
# 349                                    0.000000
# 350                                    0.100120
# 351                                    0.047632
# 352                                    0.529555
# 353                                    0.680711
# 354                                    1.017196
# 355                                    0.102958
#
# [86 rows x 7 columns]

# %%
with open('C:/Users/maran/Desktop/diff_BUM_HMM_Project/Github/diff_BUM_HMM/Reference sequences/35S pre-rRNA_refseq.seq', 'r') as file:
    ref_sequence = file.read().replace('\n', '')
#print(ref_sequence)

subsequence= []
for i in ref_sequence[269:355]: 
    subsequence.append(i)
    
#column_values = pd.Series(mylist)
#Then use the insert function to add the column. This function has the advantage to let you choose in which position you want to place the column. In the following example we will position the new column in the first position from left (by setting loc=0)
#column_values = pd.Series(subsequence)
#column_values = column_values.reset_index()
new_df_2.insert(loc=7, column='nucleotide', value=subsequence)
#print(column_values)

# %%
new_df_2.columns
# Out:
# Index(['diff diffBUMHMM deltaErb minus delta5 ',
#        'diff PEA deltaErb minus delta5', 'deltaSHAPE',
#        'SHAPE norm reactivity delta5 rep1',
#        'SHAPE norm reactivity delta5 rep2',
#        'SHAPE norm reactivity deltaerb1 rep1',
#        'SHAPE norm reactivity deltaerb1 rep2', 'nucleotide'],
#       dtype='object')

# %%
pearsonr(x, y)
 Calculates a Pearson correlation coefficient and the p-value for testing
 non-correlation.

 The Pearson correlation coefficient measures the linear relationship
 between two datasets. Strictly speaking, Pearson's correlation requires
 that each dataset be normally distributed. Like other correlation
 coefficients, this one varies between -1 and +1 with 0 implying no
 correlation. Correlations of -1 or +1 imply an exact linear
 relationship. Positive correlations imply that as x increases, so does
 y. Negative correlations imply that as x increases, y decreases.

 The p-value roughly indicates the probability of an uncorrelated system
 producing datasets that have a Pearson correlation at least as extreme
 as the one computed from these datasets. The p-values are not entirely
 reliable but are probably reasonable for datasets larger than 500 or so.

 Parameters
 ----------
 x : 1D array
 y : 1D array the same length as x

 Returns
 -------
 (Pearson's correlation coefficient,
  2-tailed p-value)

# %%
#Pearson's correlation
from scipy.stats import pearsonr, spearmanr

#diffbumhmm_delta5= new_df_2['more flexible in delta5 - DIFF BUM HMM'].tolist()
diffbumhmm_difference= new_df_2['diff diffBUMHMM deltaErb minus delta5 '].tolist()
pea_difference=new_df_2['diff PEA deltaErb minus delta5'].tolist()

#print(diffbumhmm_delta5)
#print(diffbumhmm_deltaerb)
#print(pea_difference)


#x = [1, 2, 3, 4, 5]

#corr = [2, 4, 6, 8, 10]


corr, p_value = pearsonr(diffbumhmm_difference, pea_difference)

print(corr)
print(p_value)

#corr_2, p_value_2 = spearmanr(diffbumhmm_deltaerb, pea_difference)
# Out:
# 0.41683166422522017
# 6.544107435965938e-05

# %%
fig,ax = plt.subplots(7,sharex=True,figsize=[40,10])
x = new_df_2.index

from matplotlib.ticker import LinearLocator

for i in range(7):


    if i == 0:
        ax[i].get_yaxis().set_major_locator(LinearLocator(numticks=5))
        column = new_df_2.columns[i]
        y = new_df_2[column]
        print(i)
        print(y)
        ax[i].bar(x,y)
        ax[i].set_xticklabels(x,fontsize=16)
        print(i)
        ax[i].set_ylim([-1.0, 1.0])
         
        yticks = [-0.1,-0.5,0,0.5,1.0]
        
        ax[i].set_yticklabels(yticks,fontsize=16)
        xticks = np.arange(min(x),max(x)+1)
        ax[i].set_xticks(xticks)
        nucleotides = new_df_2['nucleotide']
        ax[i].set_xticklabels(nucleotides)
        ax[i].legend([column], fontsize=15)
        ax[i].set_ylabel('diff diffBUM-HMM', rotation=0, fontsize=20, labelpad=160)
    
#    elif i == 1:
#        ax[i].get_yaxis().set_major_locator(LinearLocator(numticks=5))
#        column = new_df_2.columns[i]
#        y = new_df_2[column]
#        print(i)
#        print(y)
#        ax[i].bar(x,y)
#        ax[i].set_xticklabels(x,fontsize=16)#

#        yticks = yticks = [0.0,0.25,0.5,0.75,1.0]
#        ax[i].set_yticklabels(yticks,fontsize=16)
#        xticks = np.arange(min(x),max(x)+1)
#        ax[i].set_xticks(xticks)
#        nucleotides = new_df_2['nucleotide']
#        ax[i].set_xticklabels(nucleotides)
#        ax[i].legend([column], fontsize=15)
#        ax[i].set_ylabel('diffBUM-HMM posterior probability', rotation=0, fontsize=20, labelpad=160)
        
    elif i == 1:
        ax[i].get_yaxis().set_major_locator(LinearLocator(numticks=5))
        column = new_df_2.columns[i]
        y = new_df_2[column]
        print(i)
        print(y)
        ax[i].bar(x,y, color=(1.0, 0.0, 0.0))
        
        yticks = [-0.5,-0.25,0,0.25,0.5]
        ax[i].set_ylim([-0.5, 0.5])
        
        ax[i].set_yticklabels(yticks,fontsize=16)
        
        xticks = np.arange(min(x),max(x)+1)
        ax[i].set_xticks(xticks)
        nucleotides = new_df_2['nucleotide']
        ax[i].set_xticklabels(nucleotides)
        ax[i].legend([column], fontsize=15)
        ax[i].set_ylabel('PEA difference', rotation=0, fontsize=20, labelpad=100)
    
    
    
    elif i == 2:
        ax[i].get_yaxis().set_major_locator(LinearLocator(numticks=5))
        column = new_df_2.columns[i]
        y = new_df_2[column]
        print(i)
        print(y)
        ax[i].bar(x,y, color=(0.5, 0, 0.5))
        ax[i].set_xticklabels(x,fontsize=16)
        print(y)
        print(x)
        #print(i)
        #miny = -0.5
        #maxy = 0.5
        
        #yticks = np.arange(miny,maxy+1,0.25)
        yticks = [-0.5,-0.25,0,0.25,0.5]
        ax[i].set_ylim([-0.5, 0.5])
        ax[i].set_yticklabels(yticks,fontsize=16)
        xticks = np.arange(min(x),max(x)+1)
        ax[i].set_xticks(xticks)
        nucleotides = new_df_2['nucleotide']
        ax[i].set_xticklabels(nucleotides)
        ax[i].legend([column], fontsize=15)
        ax[i].set_ylabel('deltaSHAPE', rotation=0, fontsize=20, labelpad=100)
        
    elif i >= 3 and i < 6:
        ax[i].get_yaxis().set_major_locator(LinearLocator(numticks=5))
        column = new_df_2.columns[i]
        y = new_df_2[column]
        print(i)
        print(y)
        
        miny = 0
        maxy = 2
        yticks = np.arange(miny,maxy+1,0.5)
        ax[i].set_yticklabels(yticks,fontsize=16)
        ax[i].set_ylim([0, 2.0])
        
        
        ax[i].bar(x,y, color=(0.0, 1.0, 0.0))
    
        print(y)
        print(x)

        ax[i].set_yticklabels(yticks,fontsize=16)
        xticks = np.arange(min(x),max(x)+1)
        ax[i].set_xticks(xticks)
        nucleotides = new_df_2['nucleotide']
        ax[i].set_xticklabels(nucleotides)
        ax[i].legend([column], fontsize=15)
        ax[i].set_ylabel('SHAPE reactivity', rotation=0, fontsize=20, labelpad=100)

    elif i == 6:
        ax[i].get_yaxis().set_major_locator(LinearLocator(numticks=5))
        column = new_df_2.columns[i]
        y = new_df_2[column]
        print(i)
        print(y)
        
        miny = 0
        maxy = 2
        yticks = np.arange(miny,maxy+1,0.5)
        ax[i].set_yticklabels(yticks,fontsize=16)
        ax[i].set_ylim([0, 2.0])
        
        
        ax[i].bar(x,y, color=(0.0, 1.0, 0.0))
    
        print(y)
        print(x)

        ax[i].set_yticklabels(yticks,fontsize=16)
        xticks = np.arange(min(x),max(x)+1)
        ax[i].set_xticks(xticks)
        nucleotides = new_df_2['nucleotide']
        ax[i].set_xticklabels(nucleotides)
        ax[i].legend([column], fontsize=15)
        ax[i].set_ylabel('SHAPE reactivity', rotation=0, fontsize=20, labelpad=100)        
        ax[i].set_xlabel('Nucleotide (positions 270-355)', fontsize=20)
        
        
fig.savefig("diff_BUM_HMM_vs_PEAdifference_vs_deltaSHAPE_vs_dStructreactivities_plot_270_355_all_.pdf",dpi=400)
# Out:
# 0
# positions
# 270   -1.585893e-07
# 271    1.407343e-13
# 272    1.036717e-11
# 273    3.946810e-28
# 274    3.802900e-28
# 275    8.958519e-11
# 276    6.808013e-22
# 277    1.119753e-20
# 278    1.371585e-34
# 279    6.115684e-23
# 280    1.497805e-05
# 281    9.950746e-01
# 282    9.985545e-01
# 283    2.849179e-27
# 284    8.166069e-78
# 285    4.790286e-26
# 286    7.401482e-10
# 287    1.026336e-20
# 288    1.591416e-26
# 293    0.000000
# 294    0.000000
# 295    0.000000
# 296    0.000000
# 297    0.000000
# 298    0.000000
# 299    0.000000
#          ...
# 326    0.000000
# 327    0.258005
# 328    0.009528
# 329    0.000000
# 330    0.000000
# 331    0.000000
# 332    0.000000
# 333    0.000000
# 334    0.000000
# 335    0.000000
# 336    0.000000
# 337    0.000000
# 338    0.736450
# 339    0.861267
# 340    2.472710
# 341    1.007182
# 342    0.097632
# 343    0.000000
# 344    0.000000
# 345    0.000000
# 346    0.118643
# 347    0.085148
# 348    0.000000
# 349    0.000000
# 350    0.087014
# 351    0.000000
# 352    0.136353
# 353    0.813603
# 354    1.835039
# 355    0.000000
# Name: SHAPE norm reactivity delta5 rep2, Length: 86, dtype: float64
# Int64Index([270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282,
#             283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295,
#             296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308,
#             309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321,
#             322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334,
#             335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347,
#             348, 349, 350, 351, 352, 353, 354, 355],
#            dtype='int64', name='positions')
# 5
# positions
# 270    0.014596
# 271    0.064782
# 272    0.063383
# 273    0.011836
# 274    0.060982
# 275    0.126413
# 276    0.083320
# 277    0.050115
# 278    0.058735
# 279    0.010071
# 280    0.114555
# 281    0.191625
# 282    0.637922
# 283    0.000000
# 284    0.000000
# 285    0.000000
# 286    0.091287
# 287    0.202838
# 288    0.041043
# 289    0.000000
# 290    0.109343
# 291    0.062476
# 292    0.000000
# 293    0.000000
# 294    0.000000
# 295    0.000000
# 296    0.000000
# 297    0.064374
# 298    0.223585
# 299    0.066458
#          ...
# 326    0.221705
# 327    1.385671
# 328    0.783365
# 329    0.180585
# 330    0.000000
# 331    0.222146
# 332    0.135093
# 333    0.044965
# 334    0.148980
# 335    0.045494
# 336    0.093017
# 337    0.269417
# 338    0.774346
# 339    0.579604
# 340    1.033732
# 341    0.223553
# 342    0.000000
# 343    0.000000
# 344    0.000000
# 345    0.000000
# 346    0.000000
# 347    0.074712
# 348    0.256434
# 349    0.106574
# 350    0.000000
# 351    0.247528
# 352    0.476943
# 353    1.175464
# 354    2.054480
# 355    0.233209
# Name: SHAPE norm reactivity deltaerb1 rep1, Length: 86, dtype: float64
# positions
# 270    0.014596
# 271    0.064782
# 272    0.063383
# 273    0.011836
# 274    0.060982
# 275    0.126413
# 276    0.083320
# 277    0.050115
# 278    0.058735
# 279    0.010071
# 280    0.114555
# 281    0.191625
# 282    0.637922
# 283    0.000000
# 284    0.000000
# 285    0.000000
# 286    0.091287
# 287    0.202838
# 288    0.041043
# 289    0.000000
# 290    0.109343
# 291    0.062476
# 292    0.000000
# 293    0.000000
# 294    0.000000
# 295    0.000000
# 296    0.000000
# 297    0.064374
# 298    0.223585
# 299    0.066458
#          ...
# 326    0.221705
# 327    1.385671
# 328    0.783365
# 329    0.180585
# 330    0.000000
# 331    0.222146
# 332    0.135093
# 333    0.044965
# 334    0.148980
# 335    0.045494
# 336    0.093017
# 337    0.269417
# 338    0.774346
# 339    0.579604
# 340    1.033732
# 341    0.223553
# 342    0.000000
# 343    0.000000
# 344    0.000000
# 345    0.000000
# 346    0.000000
# 347    0.074712
# 348    0.256434
# 349    0.106574
# 350    0.000000
# 351    0.247528
# 352    0.476943
# 353    1.175464
# 354    2.054480
# 355    0.233209
# Name: SHAPE norm reactivity deltaerb1 rep1, Length: 86, dtype: float64
# Int64Index([270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282,
#             283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295,
#             296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308,
#             309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321,
#             322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334,
#             335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347,
#             348, 349, 350, 351, 352, 353, 354, 355],
#            dtype='int64', name='positions')
# 6
# positions
# 270    0.000000
# 271    0.000000
# 272    0.000000
# 273    0.000000
# 274    0.000000
# 275    0.000000
# 276    0.000000
# 277    0.000000
# 278    0.000000
# 279    0.000000
# 280    0.004525
# 281    0.044275
# 282    0.744183
# 283    0.000000
# 284    0.000000
# 285    0.000000
# 286    0.006713
# 287    0.000000
# 288    0.000000
# 289    0.000000
# 290    0.000000
# 291    0.000000
# 292    0.011153
# 293    0.000000
# 294    0.000000
# 295    0.045040
# 296    0.000000
# 297    0.000000
# 298    0.000000
# 299    0.066057
#          ...
# 326    0.000000
# 327    0.883871
# 328    0.660390
# 329    0.000000
# 330    0.000000
# 331    0.000000
# 332    0.042891
# 333    0.000000
# 334    0.000000
# 335    0.000000
# 336    0.000000
# 337    0.000000
# 338    0.933664
# 339    0.384905
# 340    0.593638
# 341    0.000000
# 342    0.000000
# 343    0.000000
# 344    0.000000
# 345    0.000000
# 346    0.000000
# 347    0.000000
# 348    0.000000
# 349    0.000000
# 350    0.100120
# 351    0.047632
# 352    0.529555
# 353    0.680711
# 354    1.017196
# 355    0.102958
# Name: SHAPE norm reactivity deltaerb1 rep2, Length: 86, dtype: float64
# positions
# 270    0.000000
# 271    0.000000
# 272    0.000000
# 273    0.000000
# 274    0.000000
# 275    0.000000
# 276    0.000000
# 277    0.000000
# 278    0.000000
# 279    0.000000
# 280    0.004525
# 281    0.044275
# 282    0.744183
# 283    0.000000
# 284    0.000000
# 285    0.000000
# 286    0.006713
# 287    0.000000
# 288    0.000000
# 289    0.000000
# 290    0.000000
# 291    0.000000
# 292    0.011153
# 293    0.000000
# 294    0.000000
# 295    0.045040
# 296    0.000000
# 297    0.000000
# 298    0.000000
# 299    0.066057
#          ...
# 326    0.000000
# 327    0.883871
# 328    0.660390
# 329    0.000000
# 330    0.000000
# 331    0.000000
# 332    0.042891
# 333    0.000000
# 334    0.000000
# 335    0.000000
# 336    0.000000
# 337    0.000000
# 338    0.933664
# 339    0.384905
# 340    0.593638
# 341    0.000000
# 342    0.000000
# 343    0.000000
# 344    0.000000
# 345    0.000000
# 346    0.000000
# 347    0.000000
# 348    0.000000
# 349    0.000000
# 350    0.100120
# 351    0.047632
# 352    0.529555
# 353    0.680711
# 354    1.017196
# 355    0.102958
# Name: SHAPE norm reactivity deltaerb1 rep2, Length: 86, dtype: float64
# Int64Index([270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282,
#             283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295,
#             296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308,
#             309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321,
#             322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334,
#             335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347,
#             348, 349, 350, 351, 352, 353, 354, 355],
#            dtype='int64', name='positions')
